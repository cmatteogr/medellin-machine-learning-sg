# %% [markdown]
# # Basic Supervised Learning model
# Learn the supervised learning model basics

# %%
# Install the project libraries
# !pip install pandas
# !pip install -U scikit-learn
# !pip install -U matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-learn) (3.3.0)
# Requirement already satisfied: matplotlib in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\cesar_nha4smq\onedrive\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## Medellin properties price prediction
# Using the Medellin properties dataset 2023, predict the property price.
#
# You can download the dataset from: https://www.kaggle.com/datasets/cesaregr/medelln-properties

# %%
# Import python libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 1. Frame the problem
# The goal es predict the Medellin properties price using the properties features: geolocation, area, # bathrooms, # rooms, etc.

# %% [markdown]
# ### 2. Selec the Performance Measure
# In order to identify how well our model is doing, we can calculate the difference between the real and predicted value. The performance measure to use is Mean Squared Error (MSE). Later we will understand how it work

# %% [markdown]
# ### 3. Download and read the Data
# The data is in the file named 'medellin_properties.csv'

# %% [markdown]
# ### 4. Take a look at the dataset - Analyze the dataset
# Review the dataset, understand what it cotains, check data quality, understand the data limitations, the risks, the non-relevant data, etc.

# %%
# Read medellin_properties file
properties_filepath = 'medellin_properties.csv'
medellin_properties_df = pd.read_csv(properties_filepath)
medellin_properties_df
# Out:
#                       neighbourhood  latitude  longitude property_type  \
# 0                        Suramerica  6.186203 -75.599437   Apartamento
# 1                          Escobero  6.162800 -75.573519   Apartamento
# 2                         Castropol  6.216140 -75.566970   Apartamento
# 3                            Toledo  6.162762 -75.639307          Casa
# 4                       La pilarica  6.247638 -75.565815   Apartamento
# ...                             ...       ...        ...           ...
# 9923             Loma de los Bernal  6.213318 -75.607806   Apartamento
# 9924  Conjunto residencial san jose  6.157310 -75.578221   Apartamento
# 9925                         Centro  6.244732 -75.560750   Apartamento
# 9926                     La america  6.254452 -75.611331   Apartamento
# 9927                     La america  6.250978 -75.604589   Apartamento
#
#           price  rooms  baths   area  administration_price  age  garages  \
# 0     435000000    3.0    2.0   83.0              354400.0  1.0      1.0
# 1     680000000    3.0    4.0  124.0              480000.0  2.0      2.0
# 2     900000000    3.0    3.0  111.0              813000.0  1.0      2.0
# 3     650000000    3.0    2.0  127.0                   0.0  2.0      1.0
# 4     320000000    3.0    2.0   72.0              250000.0  NaN      2.0
# ...         ...    ...    ...    ...                   ...  ...      ...
# 9923  685000000    3.0    3.0   94.0              380000.0  1.0      2.0
# 9924  582000000    3.0    2.0   88.0                   0.0  2.0      1.0
# 9925  320000000    3.0    2.0   59.0                   0.0  NaN      NaN
# 9926  450000000    4.0    3.0  147.0                   0.0  3.0      1.0
# 9927  245000000    2.0    2.0   51.0               50000.0  2.0      NaN
#
#       stratum
# 0           4
# 1           4
# 2           6
# 3           4
# 4           5
# ...       ...
# 9923        5
# 9924        4
# 9925        4
# 9926        3
# 9927        4
#
# [9928 rows x 12 columns]

# %% [markdown]
# ### 5. Create a Test set
# Create a test set to evaluate the model performance. The train dataset and train dataset MUST NOT share relations/transformations. It could generate bias

# %%
train_set, test_set = train_test_split(medellin_properties_df, test_size=0.2, random_state=42)
train_set
# Out:
#             neighbourhood  latitude  longitude property_type       price  \
# 6723      Doce de Octubre  6.299431 -75.584218   Apartamento   130000000
# 2291   Loma de las brujas  6.155710 -75.566498   Apartamento  1550000000
# 9785       Loma del Indio  6.209064 -75.567698   Apartamento   432000000
# 4170       Las lomas no.1  6.203481 -75.571659   Apartamento   620000000
# 5804              Robledo  6.284734 -75.614330   Apartamento    89000000
# ...                   ...       ...        ...           ...         ...
# 5734         Benedictinos  6.179084 -75.574668          Casa  2350000000
# 5191  LOMA DEL ESMERALDAL  6.167286 -75.583696   Apartamento   500000000
# 5390           Las Palmas  6.154057 -75.532461          Casa  1890000000
# 860          Los naranjos  6.187188 -75.659903   Apartamento   800000000
# 7270               Palmas  6.174934 -75.525864          Casa  3950000000
#
#       rooms  baths    area  administration_price  age  garages  stratum
# 6723    4.0    3.0   72.00                   0.0  2.0      NaN        2
# 2291    3.0    4.0  181.00              570000.0  1.0      2.0        5
# 9785    3.0    2.0   76.00              358000.0  2.0      1.0        4
# 4170    4.0    3.0  117.00              480000.0  3.0      1.0        6
# 5804    2.0    1.0   45.95               15000.0  NaN      NaN        1
# ...     ...    ...     ...                   ...  ...      ...      ...
# 5734    3.0    4.0  330.00              900000.0  2.0      2.0        5
# 5191    3.0    2.0   92.00                   0.0  NaN      NaN        5
# 5390    4.0    5.0  220.00              570000.0  NaN      4.0        6
# 860     2.0    3.0  120.00              500000.0  1.0      1.0        5
# 7270    4.0    4.0  366.00             1093000.0  NaN      4.0        6
#
# [7942 rows x 12 columns]

# %% [markdown]
# ### 6. Prepare Data for Machine Learning Algorithms
# Apply the transformations needed to prepare the data to train the model. Remove irrelevant features, handle outliers and anomalies, handle missing values, scale features, etc. In this section we will only remove the irrelevant features, in following session we will perform more transformation to improve the data quality and prepare better the data.

# %%
train_set.drop(columns=['neighbourhood', 'property_type'], inplace=True)
test_set.drop(columns=['neighbourhood', 'property_type'], inplace=True)
train_set
# Out:
#       latitude  longitude       price  rooms  baths    area  \
# 6723  6.299431 -75.584218   130000000    4.0    3.0   72.00
# 2291  6.155710 -75.566498  1550000000    3.0    4.0  181.00
# 9785  6.209064 -75.567698   432000000    3.0    2.0   76.00
# 4170  6.203481 -75.571659   620000000    4.0    3.0  117.00
# 5804  6.284734 -75.614330    89000000    2.0    1.0   45.95
# ...        ...        ...         ...    ...    ...     ...
# 5734  6.179084 -75.574668  2350000000    3.0    4.0  330.00
# 5191  6.167286 -75.583696   500000000    3.0    2.0   92.00
# 5390  6.154057 -75.532461  1890000000    4.0    5.0  220.00
# 860   6.187188 -75.659903   800000000    2.0    3.0  120.00
# 7270  6.174934 -75.525864  3950000000    4.0    4.0  366.00
#
#       administration_price  age  garages  stratum
# 6723                   0.0  2.0      NaN        2
# 2291              570000.0  1.0      2.0        5
# 9785              358000.0  2.0      1.0        4
# 4170              480000.0  3.0      1.0        6
# 5804               15000.0  NaN      NaN        1
# ...                    ...  ...      ...      ...
# 5734              900000.0  2.0      2.0        5
# 5191                   0.0  NaN      NaN        5
# 5390              570000.0  NaN      4.0        6
# 860               500000.0  1.0      1.0        5
# 7270             1093000.0  NaN      4.0        6
#
# [7942 rows x 10 columns]

# %% [markdown]
# ### 7. Train the model
# Select a model and use the training dataset to train the model. In following sessions we will improve the model (fine-tune).
#
# The ML model selected is Random Tree algorithm.

# %%
# Build X and y datasets. Training and Testing
y_train = train_set['price']
X_train = train_set.drop(columns='price')
y_test = test_set['price']
X_test = test_set.drop(columns='price')

# %%
X_train
# Out:
#       latitude  longitude  rooms  baths    area  administration_price  age  \
# 6723  6.299431 -75.584218    4.0    3.0   72.00                   0.0  2.0
# 2291  6.155710 -75.566498    3.0    4.0  181.00              570000.0  1.0
# 9785  6.209064 -75.567698    3.0    2.0   76.00              358000.0  2.0
# 4170  6.203481 -75.571659    4.0    3.0  117.00              480000.0  3.0
# 5804  6.284734 -75.614330    2.0    1.0   45.95               15000.0  NaN
# ...        ...        ...    ...    ...     ...                   ...  ...
# 5734  6.179084 -75.574668    3.0    4.0  330.00              900000.0  2.0
# 5191  6.167286 -75.583696    3.0    2.0   92.00                   0.0  NaN
# 5390  6.154057 -75.532461    4.0    5.0  220.00              570000.0  NaN
# 860   6.187188 -75.659903    2.0    3.0  120.00              500000.0  1.0
# 7270  6.174934 -75.525864    4.0    4.0  366.00             1093000.0  NaN
#
#       garages  stratum
# 6723      NaN        2
# 2291      2.0        5
# 9785      1.0        4
# 4170      1.0        6
# 5804      NaN        1
# ...       ...      ...
# 5734      2.0        5
# 5191      NaN        5
# 5390      4.0        6
# 860       1.0        5
# 7270      4.0        6
#
# [7942 rows x 9 columns]

# %%
y_test
# Out:
# 2688    890000000
# 4503    450000000
# 7135    460000000
# 7682    530000000
# 3127    290000000
#           ...
# 7517    280000000
# 6426    320000000
# 810     250000000
# 3281    260000000
# 6393    299000000
# Name: price, Length: 1986, dtype: int64

# %% [markdown]
# ##### ML Algorithms
# * Linear Regression
# * Logistic Regression
# * Support Vector Machines (SVMs)
# * Decision Trees and Random Forests
# * Neural networks2

# %% [markdown]
# To understand random forest:
#
# https://www.youtube.com/watch?v=g9c66TUylZ4
#
# https://www.youtube.com/watch?v=J4Wdy0Wc_xQ&t=91s

# %%
# Initialize the RandomForestRegressor
regr = RandomForestRegressor(n_estimators=100, random_state=42, criterion='squared_error')
# Fit the model on the training data
regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ### 8. Evaluate Model performance
# Check how well the mode is doing using the performance metric (cost function). Mean Squared Error (MSE) in this case

# %%
# Make predictions on the test data
y_pred = regr.predict(X_test)
# Evaluate the model using the root mean squared error
mse = mean_squared_error(y_test, y_pred)
print(f'MSE: {mse:.2f}')
# Out:
# MSE: 862857707347354583040.00

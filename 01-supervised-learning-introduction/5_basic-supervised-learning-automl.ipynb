# %% [markdown]
# # Basic Supervised Learning model
# Learn the supervised learning model basics

# %%
# Install the project libraries
# !pip install pandas
# !pip install -U scikit-learn
# !pip install -U matplotlib
# !pip install scikit-optimize
# !pip install catboost
# !pip install pycaret notebook
# Out:
# Requirement already satisfied: pandas in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: matplotlib in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (3.7.5)
# Collecting matplotlib
#   Using cached matplotlib-3.8.4-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.8.4-cp310-cp310-win_amd64.whl (7.7 MB)
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.5
#     Uninstalling matplotlib-3.7.5:
#       Successfully uninstalled matplotlib-3.7.5
# Successfully installed matplotlib-3.8.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pycaret 3.3.0 requires matplotlib<3.8.0, but you have matplotlib 3.8.4 which is incompatible.
# Requirement already satisfied: scikit-optimize in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (0.10.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-optimize) (1.4.0)
# Requirement already satisfied: pyaml>=16.9 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-optimize) (23.12.0)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-optimize) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-optimize) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-optimize) (1.4.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-optimize) (24.0)
# Requirement already satisfied: PyYAML in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.4.0)
# Requirement already satisfied: catboost in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (1.2.3)
# Requirement already satisfied: graphviz in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from catboost) (3.8.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from catboost) (2.1.4)
# Requirement already satisfied: scipy in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from catboost) (5.20.0)
# Requirement already satisfied: six in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib->catboost) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from plotly->catboost) (8.2.3)
# Requirement already satisfied: pycaret in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (3.3.0)
# Requirement already satisfied: notebook in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (7.1.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (8.23.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (8.1.2)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (4.66.2)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (3.1.3)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (1.4.0)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (0.12.2)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (4.3.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (0.59.1)
# Requirement already satisfied: requests>=2.27.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (2.31.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (5.9.8)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (2.1.5)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (7.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (3.4.1)
# Collecting matplotlib<3.8.0 (from pycaret)
#   Using cached matplotlib-3.7.5-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (5.20.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (0.14.1)
# Requirement already satisfied: sktime>=0.26.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (0.28.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from notebook) (2.13.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from notebook) (2.26.0)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from notebook) (4.1.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from notebook) (6.4)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: packaging in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from deprecation>=2.1.0->pycaret) (24.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.4.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.18.1)
# Requirement already satisfied: decorator in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.2)
# Requirement already satisfied: exceptiongroup in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (1.2.0)
# Requirement already satisfied: typing-extensions in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (4.11.0)
# Requirement already satisfied: colorama in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.10)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.3.0)
# Requirement already satisfied: argon2-cffi in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.3)
# Requirement already satisfied: overrides in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: prometheus-client in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.20.0)
# Requirement already satisfied: pywinpty in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.0.13)
# Requirement already satisfied: pyzmq>=24 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: websocket-client in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook) (6.29.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook) (2.2.5)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook) (2.0.1)
# Requirement already satisfied: babel>=2.10 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (0.9.24)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (4.21.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.19.1)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from numba>=0.55.0->pycaret) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas<2.2.0->pycaret) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pandas<2.2.0->pycaret) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from plotly>=5.14.0->pycaret) (8.2.3)
# Requirement already satisfied: dash>=2.9.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.16.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.10)
# Requirement already satisfied: urllib3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.2.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (65.5.0)
# Requirement already satisfied: six in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from pyod>=1.1.3->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from requests>=2.27.1->pycaret) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from requests>=2.27.1->pycaret) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from requests>=2.27.1->pycaret) (2024.2.2)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from sktime>=0.26.0->pycaret) (0.7.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.2)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: retrying in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: httpcore==1.* in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.2,>=4.1.1->notebook) (1.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (306)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.2.1)
# Requirement already satisfied: wcwidth in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: webencodings in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.7.0)
# Requirement already satisfied: fqdn in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.4)
# Requirement already satisfied: uri-template in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.5)
# Requirement already satisfied: pycparser in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\cesar_0qb0xal\documents\github\medellin-machine-learning-sg\.venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.9.0.20240316)
# Using cached matplotlib-3.7.5-cp310-cp310-win_amd64.whl (7.5 MB)
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.4
#     Uninstalling matplotlib-3.8.4:
#       Successfully uninstalled matplotlib-3.8.4
# Successfully installed matplotlib-3.7.5

# %% [markdown]
# ## Medellin properties price prediction
# Using the Medellin properties dataset 2023, predict the property price.
#
# You can download the dataset from: https://www.kaggle.com/datasets/cesaregr/medelln-properties

# %%
# Import python libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ### 1. Frame the problem
# The goal es predict the Medellin properties price using the properties features: geolocation, area, # bathrooms, # rooms, etc.

# %% [markdown]
# ### 2. Selec the Performance Measure
# In order to identify how well our model is doing, we can calculate the difference between the real and predicted value. The performance measure to use is Mean Squared Error (MSE). Later we will understand how it work

# %% [markdown]
# ### 3. Download and read the Data
# The data is in the file named 'medellin_properties.csv'

# %% [markdown]
# ### 4. Take a look at the dataset - Analyze the dataset
# Review the dataset, understand what it cotains, check data quality, understand the data limitations, the risks, the non-relevant data, etc.

# %%
# Read medellin_properties file
properties_filepath = 'medellin_properties.csv'
properties_df = pd.read_csv(properties_filepath)
properties_df
# Out:
#                       neighbourhood  latitude  longitude property_type  \
# 0                        Suramerica  6.186203 -75.599437   Apartamento
# 1                          Escobero  6.162800 -75.573519   Apartamento
# 2                         Castropol  6.216140 -75.566970   Apartamento
# 3                            Toledo  6.162762 -75.639307          Casa
# 4                       La pilarica  6.247638 -75.565815   Apartamento
# ...                             ...       ...        ...           ...
# 9923             Loma de los Bernal  6.213318 -75.607806   Apartamento
# 9924  Conjunto residencial san jose  6.157310 -75.578221   Apartamento
# 9925                         Centro  6.244732 -75.560750   Apartamento
# 9926                     La america  6.254452 -75.611331   Apartamento
# 9927                     La america  6.250978 -75.604589   Apartamento
#
#           price  rooms  baths   area  administration_price  age  garages  \
# 0     435000000    3.0    2.0   83.0              354400.0  1.0      1.0
# 1     680000000    3.0    4.0  124.0              480000.0  2.0      2.0
# 2     900000000    3.0    3.0  111.0              813000.0  1.0      2.0
# 3     650000000    3.0    2.0  127.0                   0.0  2.0      1.0
# 4     320000000    3.0    2.0   72.0              250000.0  NaN      2.0
# ...         ...    ...    ...    ...                   ...  ...      ...
# 9923  685000000    3.0    3.0   94.0              380000.0  1.0      2.0
# 9924  582000000    3.0    2.0   88.0                   0.0  2.0      1.0
# 9925  320000000    3.0    2.0   59.0                   0.0  NaN      NaN
# 9926  450000000    4.0    3.0  147.0                   0.0  3.0      1.0
# 9927  245000000    2.0    2.0   51.0               50000.0  2.0      NaN
#
#       stratum
# 0           4
# 1           4
# 2           6
# 3           4
# 4           5
# ...       ...
# 9923        5
# 9924        4
# 9925        4
# 9926        3
# 9927        4
#
# [9928 rows x 12 columns]

# %% [markdown]
# ### 5. Prepare Data for Machine Learning Algorithms - Generate Train and Test set
# Apply the transformations needed to prepare the data to train the model. Remove irrelevant features, handle outliers and anomalies, handle missing values, scale features, etc.

# %%
# Remove propertyType = Proyecto. It's not into the current scope
properties_df=properties_df.loc[properties_df['property_type']!='Proyecto']

# %%
# Split features and target
y = properties_df['price']
properties_df.drop(columns='price', inplace=True)
X = properties_df.copy()
# Out:
# C:\Users\cesar_0qb0xal\AppData\Local\Temp\ipykernel_21580\3506261903.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   properties_df.drop(columns='price', inplace=True)

# %%
# Split dataset
train_set, test_set, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Copy the original test dataset to review the results later
test_o_set = test_set.copy()

# %%
# Remove irrelevant features
train_set.drop(columns=['neighbourhood'], inplace=True)
test_set.drop(columns=['neighbourhood'], inplace=True)
train_set
# Out:
#       latitude  longitude property_type  rooms  baths   area  \
# 1795  6.240919 -75.556469   Apartamento    3.0    2.0  138.0
# 5912  6.269560 -75.608969   Apartamento    3.0    2.0   71.0
# 3606  6.282073 -75.615990   Apartamento    4.0    1.0   46.0
# 8407  6.263200 -75.545278          Casa    3.0    2.0  118.0
# 8222  6.146531 -75.609541   Apartamento    3.0    2.0   63.0
# ...        ...        ...           ...    ...    ...    ...
# 5743  6.151145 -75.636623          Casa    3.0    2.0   98.0
# 5197  6.181666 -75.579754          Casa    3.0    2.0   90.0
# 5397  6.180376 -75.559996   Apartamento    3.0    2.0   67.0
# 861   6.268205 -75.559055   Apartamento    2.0    1.0   57.8
# 7281  6.268340 -75.587344   Apartamento    3.0    2.0   73.0
#
#       administration_price  age  garages  stratum
# 1795                   0.0  1.0      NaN        3
# 5912              290000.0  2.0      1.0        4
# 3606               13000.0  4.0      1.0        3
# 8407                   0.0  3.0      NaN        2
# 8222                   0.0  0.0      1.0        4
# ...                    ...  ...      ...      ...
# 5743              284000.0  3.0      1.0        4
# 5197                   0.0  NaN      NaN        5
# 5397              250000.0  2.0      1.0        5
# 861                    0.0  2.0      NaN        3
# 7281              257000.0  1.0      1.0        4
#
# [8924 rows x 10 columns]

# %%
# Replace the value in a specific column. Join Apartaestudio and Apartamento
train_set['property_type'] = train_set['property_type'].replace('Apartaestudio', 'Apartamento')
test_set['property_type'] = test_set['property_type'].replace('Apartaestudio', 'Apartamento')
# Transform the propery type to binary
train_set['property_type'] = train_set['property_type'].replace('Apartamento', 1)
train_set['property_type'] = train_set['property_type'].replace('Casa', 0)
test_set['property_type'] = test_set['property_type'].replace('Apartamento', 1)
test_set['property_type'] = test_set['property_type'].replace('Casa', 0)

# %%
from sklearn.experimental import enable_iterative_imputer 
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor

# NOTE: We will use RandomForestRegressor as estimato because there are some features highly skew
# and the BayesRidge stimator is more sensitive to outliers and data scale
imp = IterativeImputer(estimator=RandomForestRegressor()) 
# fit on the dataset 
imp.fit(train_set) 
# transform the dataset 
X_train_trans = imp.transform(train_set)
X_test_trans = imp.transform(test_set)
# Transfor to the dataset
train_set = pd.DataFrame(X_train_trans, columns=train_set.columns, index=train_set.index)
test_set = pd.DataFrame(X_test_trans, columns=test_set.columns, index=test_set.index)

# %%
from sklearn.ensemble import IsolationForest

# Remove outliers
iso_forest = IsolationForest(n_estimators=200, contamination=0.12, random_state=42)
iso_forest.fit(train_set)
train_set['outlier'] = iso_forest.predict(train_set)
test_set['outlier'] = iso_forest.predict(test_set)
# Remove global outliers
train_set = train_set[train_set['outlier'] != -1]
test_set = test_set[test_set['outlier'] != -1]
# Remove the outlier column
train_set.drop(columns='outlier', inplace=True)
test_set.drop(columns='outlier', inplace=True)
# Filter valid prices
y_train = y_train.loc[train_set.index]
y_test = y_test.loc[test_set.index]

# %%
from sklearn.preprocessing import MinMaxScaler

# Apply min-max scaler
scaler = MinMaxScaler()
scaler_model = scaler.fit(train_set)
train_scaled = scaler_model.transform(train_set)
test_scaled = scaler_model.transform(test_set)
train_set = pd.DataFrame(train_scaled, columns=train_set.columns, index=train_set.index)
test_set = pd.DataFrame(test_scaled, columns=test_set.columns, index=test_set.index)

# %%
y_train = y_train/1000000
y_test = y_test/1000000

# %% [markdown]
# ### 6. Train the model
# Select a model and use the training dataset to train the model. In following sessions we will improve the model (fine-tune).
#
# The ML model selected is Random Tree algorithm.

# %%
train_set
# Out:
#       latitude  longitude  property_type     rooms     baths      area  \
# 1795  0.891680   0.193745            1.0  0.105263  0.166667  0.253704
# 5912  0.892331   0.183180            1.0  0.105263  0.166667  0.129630
# 3606  0.892615   0.181767            1.0  0.157895  0.000000  0.083333
# 8407  0.892186   0.195997            0.0  0.105263  0.166667  0.216667
# 8222  0.889536   0.183065            1.0  0.105263  0.166667  0.114815
# ...        ...        ...            ...       ...       ...       ...
# 5743  0.889641   0.177615            0.0  0.105263  0.166667  0.179630
# 5197  0.890334   0.189059            0.0  0.105263  0.166667  0.164815
# 5397  0.890305   0.193035            1.0  0.105263  0.166667  0.122222
# 861   0.892300   0.193225            1.0  0.052632  0.000000  0.105185
# 7281  0.892303   0.187532            1.0  0.105263  0.166667  0.133333
#
#       administration_price     age   garages   stratum
# 1795              0.000000  0.2500  0.070000  0.500000
# 5912              0.000957  0.5000  0.000000  0.666667
# 3606              0.000043  1.0000  0.000000  0.500000
# 8407              0.000000  0.7500  0.020000  0.333333
# 8222              0.000000  0.0000  0.000000  0.666667
# ...                    ...     ...       ...       ...
# 5743              0.000937  0.7500  0.000000  0.666667
# 5197              0.000000  0.5275  0.073333  0.833333
# 5397              0.000825  0.5000  0.000000  0.833333
# 861               0.000000  0.5000  0.013333  0.500000
# 7281              0.000848  0.2500  0.000000  0.666667
#
# [7853 rows x 10 columns]

# %%
y_train
# Out:
# 1795    309.0
# 5912    420.0
# 3606    120.0
# 8407    190.0
# 8222    350.0
#         ...
# 5743    385.0
# 5197    375.0
# 5397    454.0
# 861     235.0
# 7281    455.0
# Name: price, Length: 7853, dtype: float64

# %% [markdown]
# ##### ML Algorithms
# * Linear Regression
# * Logistic Regression
# * Support Vector Machines (SVMs)
# * Decision Trees and Random Forests
# * Neural networks2

# %% [markdown]
# To understand random forest:
#
# https://www.youtube.com/watch?v=g9c66TUylZ4
#
# https://www.youtube.com/watch?v=J4Wdy0Wc_xQ&t=91s

# %%
# Initialize the RandomForestRegressor
regr = RandomForestRegressor(n_estimators=100, random_state=42, criterion='squared_error')
# Fit the model on the training data
regr.fit(train_set, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ### 7. Evaluate Model performance
# Check how well the mode is doing using the performance metric (cost function). Mean Squared Error (MSE) in this case

# %%
# Make predictions on the test data
y_pred = regr.predict(test_set)
# Evaluate the model using the root mean squared error
mse = mean_squared_error(y_test, y_pred)
print(f'MSE: {mse:.2f}')
# Out:
# MSE: 587611559.71

# %%
# Initialize the RandomForestRegressor (n_estimators=10)
regr = RandomForestRegressor(n_estimators=10, random_state=42, criterion='squared_error')
# Fit the model on the training data
regr.fit(train_set, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=42)

# %%
# Make predictions on the test data
y_pred = regr.predict(test_set)
# Evaluate the model using the root mean squared error
mse = mean_squared_error(y_test, y_pred)
print(f'MSE: {mse:.2f}')
# Out:
# MSE: 619931925.32

# %%
# Previous MSE
# MSE: 163'247.086'315.270'635.520.00

# Current  MSE
# MSE: 1.128'063.980.17

# %% [markdown]
# ### 8. Fine-tune the model
# Choose the best hyper parameters to get the best model performance

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid to search over
param_grid = {
    'n_estimators': [5, 10, 30, 40, 50, 100, 200, 300],  # Number of trees in the forest
    'max_depth': [None, 5, 10, 20, 30, 40, 50],  # Maximum depth of the tree
    'min_samples_split': [2, 3, 5, 10]  # Minimum number of samples required to split an internal node
}

# Initialize Random Forest Regressor algorithm 
regr = RandomForestRegressor(random_state=42, criterion='squared_error')

# Initialize GridSearchCV with the RandomForest model and the parameter grid
grid_search = GridSearchCV(estimator=regr, param_grid=param_grid, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit the GridSearchCV to the training data
grid_search.fit(train_set, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 5, 10, 20, 30, 40, 50],
#                          'min_samples_split': [2, 3, 5, 10],
#                          'n_estimators': [5, 10, 30, 40, 50, 100, 200, 300]},
#              scoring='neg_mean_squared_error')

# %%
# Print the best parameters and the best score
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best score (negative mean squared error): {grid_search.best_score_}")

# Use the best estimator to make predictions on the test set
best_model = grid_search.best_estimator_
# Make predictions on the test data
y_pred = best_model.predict(test_set)
# Evaluate the model using the root mean squared error
mse = mean_squared_error(y_test, y_pred)
print(f'MSE: {mse:.2f}')
# Out:
# Best parameters: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 40}
# Best score (negative mean squared error): -555983562.8190459
# MSE: 702527800.64

# %%
# Previous MSE
# MSE: 151'073.261'725.553'917.952.00

# Current MSE
# MSE: 223'316.391.03

# %% [markdown]
# ### 9. Fine-tune the model - Experimentation
# Choose the best hyper parameters to get the best model performance. Using other techniques. BayesSearchCV

# %%
from skopt import BayesSearchCV
from skopt.space import Real, Integer

# Define the parameter bayesian to search over
param_space = {
    'n_estimators': Integer(10, 100),  # Number of trees in the forest
    'max_depth': Integer(1, 50),       # Maximum depth of the tree
    'min_samples_split': Real(0.01, 1.0, 'uniform'),  # Minimum number of samples required to split an internal node
}

# Initialize Random Forest Regressor algorithm 
regr = RandomForestRegressor(random_state=42, criterion='squared_error')

optimizer = BayesSearchCV(
    estimator=RandomForestRegressor(random_state=42),
    search_spaces=param_space,
    n_iter=25,  # Number of parameter settings that are sampled
    cv=5,       # 5-fold cross-validation
    random_state=42
)

# Fit the BayesSearchCV to the training data
optimizer.fit(train_set, y_train)
# Out:
# BayesSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42), n_iter=25,
#               random_state=42,
#               search_spaces={'max_depth': Integer(low=1, high=50, prior='uniform', transform='normalize'),
#                              'min_samples_split': Real(low=0.01, high=1.0, prior='uniform', transform='normalize'),
#                              'n_estimators': Integer(low=10, high=100, prior='uniform', transform='normalize')})

# %%
# Print the best parameters and the best score
print(f"Best parameters: {optimizer.best_params_}")
print(f"Best score (negative mean squared error): {optimizer.best_score_}")

# Use the best estimator to make predictions on the test set
best_model = optimizer.best_estimator_
# Make predictions on the test data
y_pred = best_model.predict(test_set)
# Evaluate the model using the root mean squared error
mse = mean_squared_error(y_test, y_pred)
print(f'MSE: {mse:.2f}')
# Out:
# Best parameters: OrderedDict([('max_depth', 23), ('min_samples_split', 0.9195352964526833), ('n_estimators', 19)])
# Best score (negative mean squared error): -1.1267886241582403
# MSE: 50602784.03

# %%
# Previous MSE
# MSE: 223'316.391.03

# Current MSE
# MSE: 49'355.045.36

# %% [markdown]
# Using an a different algorithm. CatBoost
# https://catboost.ai/en/docs/

# %%
from catboost import CatBoostRegressor

# Define the parameter bayesian to search over
param_space = {
    'learning_rate': Real(0.01, 0.3),
    'depth': Integer(3, 16),
    'iterations': Integer(10, 100),
    'l2_leaf_reg': Real(1, 10)
}
# Initalize the model
catboost = CatBoostRegressor(verbose=1, random_state=42)

optimizer = BayesSearchCV(
    estimator=catboost,
    search_spaces=param_space,
    n_iter=30,  # Number of parameter settings that are sampled
    cv=4,       # 5-fold cross-validation
    random_state=42
)

optimizer.fit(train_set, y_train)
# Out:
# 0:	learn: 25801.9318959	total: 140ms	remaining: 10.3s
# 1:	learn: 25731.5270491	total: 142ms	remaining: 5.18s
# 2:	learn: 25653.3029278	total: 146ms	remaining: 3.49s
# 3:	learn: 25577.2670042	total: 150ms	remaining: 2.66s
# 4:	learn: 25501.8100310	total: 154ms	remaining: 2.16s
# 5:	learn: 25359.9565719	total: 159ms	remaining: 1.83s
# 6:	learn: 25284.3700083	total: 161ms	remaining: 1.57s
# 7:	learn: 25213.4952686	total: 164ms	remaining: 1.37s
# 8:	learn: 25155.2129942	total: 169ms	remaining: 1.24s
# 9:	learn: 25068.0029706	total: 174ms	remaining: 1.13s
# 10:	learn: 24983.0105259	total: 178ms	remaining: 1.03s
# 11:	learn: 24832.8525704	total: 181ms	remaining: 952ms
# 12:	learn: 24770.7976475	total: 186ms	remaining: 889ms
# 13:	learn: 24685.9130297	total: 192ms	remaining: 836ms
# 14:	learn: 24618.6739887	total: 197ms	remaining: 787ms
# 15:	learn: 24550.6949195	total: 202ms	remaining: 744ms
# 29:	learn: 15043.5263291	total: 11.5s	remaining: 19.2s
# 30:	learn: 15004.2172582	total: 11.7s	remaining: 18.5s
# 31:	learn: 14964.9517255	total: 11.8s	remaining: 17.7s
# 32:	learn: 14926.0157378	total: 11.8s	remaining: 16.8s
# 33:	learn: 14887.1467144	total: 12.6s	remaining: 17.1s
# 34:	learn: 14848.3853658	total: 12.7s	remaining: 16.4s
# 35:	learn: 14809.8631720	total: 12.8s	remaining: 15.6s
# 36:	learn: 14771.2490038	total: 13.8s	remaining: 16s
# 37:	learn: 14732.8509601	total: 14.7s	remaining: 16.2s
# 38:	learn: 14694.6230029	total: 15.6s	remaining: 16.4s
# 39:	learn: 14656.3876841	total: 16.3s	remaining: 16.3s
# 40:	learn: 14611.5248288	total: 17.1s	remaining: 16.3s
# 41:	learn: 14573.7321287	total: 17.5s	remaining: 15.8s
# 42:	learn: 14536.0327017	total: 18.3s	remaining: 15.7s
# 43:	learn: 14498.5999662	total: 18.5s	remaining: 15.1s
# 44:	learn: 14461.3040050	total: 19.2s	remaining: 15s
# 45:	learn: 14424.0037935	total: 20s	remaining: 14.8s
# 46:	learn: 14384.8057387	total: 20.8s	remaining: 14.6s
# 47:	learn: 14347.4165889	total: 21.6s	remaining: 14.4s
# 48:	learn: 14310.7061170	total: 21.7s	remaining: 13.7s
# 49:	learn: 14274.1243586	total: 21.8s	remaining: 13.1s
# 50:	learn: 14237.4166597	total: 22.6s	remaining: 12.9s
# 51:	learn: 14201.0167807	total: 23.4s	remaining: 12.6s
# 52:	learn: 14164.5548879	total: 24.2s	remaining: 12.3s
# 53:	learn: 14128.5531353	total: 24.2s	remaining: 11.7s
# 54:	learn: 14092.6455305	total: 24.2s	remaining: 11s
# 55:	learn: 14056.7936107	total: 24.3s	remaining: 10.4s
# 56:	learn: 14021.1044244	total: 25.2s	remaining: 10.2s
# 57:	learn: 13985.5534836	total: 26.1s	remaining: 9.9s
# 58:	learn: 13949.9789593	total: 27s	remaining: 9.6s
# 59:	learn: 13914.7072004	total: 27.9s	remaining: 9.29s
# 60:	learn: 13879.3000264	total: 28.8s	remaining: 8.97s
# 61:	learn: 13843.8989636	total: 29.8s	remaining: 8.65s
# 62:	learn: 13808.8569456	total: 30.3s	remaining: 8.17s
# 63:	learn: 13782.4963750	total: 31.2s	remaining: 7.81s
# 64:	learn: 13747.8001362	total: 31.7s	remaining: 7.31s
# 65:	learn: 13713.3307084	total: 31.8s	remaining: 6.75s
# 66:	learn: 13678.0820377	total: 32.7s	remaining: 6.33s
# 67:	learn: 13643.8149084	total: 33.4s	remaining: 5.9s
# 68:	learn: 13609.5715703	total: 34.2s	remaining: 5.45s
# 69:	learn: 13575.6013361	total: 34.2s	remaining: 4.89s
# 70:	learn: 13541.6996342	total: 35s	remaining: 4.44s
# 71:	learn: 13507.8427357	total: 35.8s	remaining: 3.98s
# 72:	learn: 13474.0146013	total: 36.5s	remaining: 3.5s
# 73:	learn: 13440.5123322	total: 37.3s	remaining: 3.02s
# 17:	learn: 22933.1721131	total: 9.48s	remaining: 22.1s
# 18:	learn: 22926.6922585	total: 9.5s	remaining: 20.5s
# 19:	learn: 22921.0415146	total: 9.51s	remaining: 19s
# 20:	learn: 22916.1153694	total: 9.96s	remaining: 18.5s
# 21:	learn: 22909.0097594	total: 9.97s	remaining: 17.2s
# 22:	learn: 22902.2771943	total: 10.8s	remaining: 17.4s
# 23:	learn: 22895.6068830	total: 10.9s	remaining: 16.4s
# 24:	learn: 22888.9209144	total: 11.9s	remaining: 16.7s
# 25:	learn: 22876.1158328	total: 13.1s	remaining: 17.2s
# 26:	learn: 22863.0544233	total: 14.1s	remaining: 17.2s
# 27:	learn: 22850.2553742	total: 14.3s	remaining: 16.4s
# 28:	learn: 22837.2001858	total: 15.3s	remaining: 16.3s
# 29:	learn: 22830.5720938	total: 15.3s	remaining: 15.3s
# 30:	learn: 22823.9473652	total: 15.3s	remaining: 14.3s
# 31:	learn: 22817.8164227	total: 15.3s	remaining: 13.4s
# 32:	learn: 22810.8082262	total: 15.4s	remaining: 12.6s
# 33:	learn: 22797.4633829	total: 16.3s	remaining: 12.5s
# 34:	learn: 22779.5606349	total: 16.9s	remaining: 12.1s
# 35:	learn: 22766.5277084	total: 16.9s	remaining: 11.3s
# 36:	learn: 22759.9832555	total: 17.9s	remaining: 11.1s
# 37:	learn: 22753.6361923	total: 19s	remaining: 11s
# 38:	learn: 22747.0235997	total: 20.1s	remaining: 10.8s
# 39:	learn: 22740.4342815	total: 20.6s	remaining: 10.3s
# 40:	learn: 22733.7927341	total: 20.6s	remaining: 9.55s
# 41:	learn: 22726.7651543	total: 20.9s	remaining: 8.94s
# 42:	learn: 22720.4687723	total: 20.9s	remaining: 8.25s
# 43:	learn: 22713.9137599	total: 21.4s	remaining: 7.77s
# 44:	learn: 22707.3789291	total: 21.4s	remaining: 7.13s
# 45:	learn: 22700.4818744	total: 21.5s	remaining: 6.55s
# 46:	learn: 22693.6070841	total: 21.5s	remaining: 5.96s
# 47:	learn: 22681.0742190	total: 21.5s	remaining: 5.39s
# 48:	learn: 22668.4928128	total: 22.5s	remaining: 5.05s
# 49:	learn: 22655.8801599	total: 23.5s	remaining: 4.69s
# 50:	learn: 22649.3941191	total: 23.5s	remaining: 4.14s
# 51:	learn: 22642.5845405	total: 23.5s	remaining: 3.61s
# 52:	learn: 22636.5500498	total: 23.5s	remaining: 3.1s
# 53:	learn: 22629.7067910	total: 23.5s	remaining: 2.62s
# 54:	learn: 22623.2815312	total: 23.8s	remaining: 2.16s
# 55:	learn: 22616.7831997	total: 24.7s	remaining: 1.76s
# 56:	learn: 22604.3196410	total: 24.7s	remaining: 1.3s
# 57:	learn: 22591.9054261	total: 24.8s	remaining: 856ms
# 58:	learn: 22585.4784459	total: 24.9s	remaining: 421ms
# 59:	learn: 22579.0412647	total: 24.9s	remaining: 0us
# BayesSearchCV(cv=4,
#               estimator=<catboost.core.CatBoostRegressor object at 0x0000018F3375EC80>,
#               n_iter=30, random_state=42,
#               search_spaces={'depth': Integer(low=3, high=16, prior='uniform', transform='normalize'),
#                              'iterations': Integer(low=10, high=100, prior='uniform', transform='normalize'),
#                              'l2_leaf_reg': Real(low=1, high=10, prior='uniform', transform='normalize'),
#                              'learning_rate': Real(low=0.01, high=0.3, prior='uniform', transform='normalize')})

# %%
# Print the best parameters and the best score
print(f"Best parameters: {optimizer.best_params_}")
print(f"Best score (negative mean squared error): {optimizer.best_score_}")

# Use the best estimator to make predictions on the test set
best_model = optimizer.best_estimator_
# Make predictions on the test data
y_pred = best_model.predict(test_set)
# Evaluate the model using the root mean squared error
mse = mean_squared_error(y_test, y_pred)
print(f'MSE: {mse:.2f}')
# Out:
# Best parameters: OrderedDict([('depth', 16), ('iterations', 60), ('l2_leaf_reg', 9.738967273796947), ('learning_rate', 0.01)])
# Best score (negative mean squared error): -0.007921650068484637
# MSE: 50487851.20

# %%
# Previous MSE
# MSE: 49'355.045.36

# Current MSE
# MSE: 50'487.851.20

# %%
mae = mean_absolute_error(y_test, y_pred)
print(f'MAE: {mae:.2f}')
# Out:
# MAE: 771.66

# %% [markdown]
# ### 9. Review results
# Review the final results after apply fine-tuning

# %%
# Get the valid result
test_o_set = test_o_set.loc[test_set.index] 
test_o_set['price'] = y_test
test_o_set['pred_price'] = y_pred
test_o_set.head(30)
# Out:
#                            neighbourhood  latitude  longitude property_type  \
# 6565                       López de Mesa  6.254569 -75.599280   Apartamento
# 9296                            Calasanz  6.270774 -75.600117   Apartamento
# 361                  Vegas de la doctora  6.144721 -75.610881   Apartamento
# 1263                          El Poblado  6.203481 -75.571659   Apartamento
# 3043                sabaneta aves marias  6.148975 -75.617243   Apartamento
# 9513                          suramerica  6.160509 -75.628399          Casa
# 1157                      Asomadera no.2  6.226906 -75.561853   Apartamento
# 2875                        Buenos Aires  6.237129 -75.556054   Apartamento
# 7352                               Belén  6.236265 -75.595370   Apartamento
# 6107                            Envigado  6.239340 -75.570055   Apartamento
# 8719                           Las vegas  6.182117 -75.575173   Apartamento
# 4495                       Villa Hermosa  6.252792 -75.554824          Casa
# 7376                           San Diego  6.230294 -75.566478   Apartamento
# 7638                       La candelaria  6.250055 -75.566834   Apartamento
# 2397                         Las Lomitas  6.149414 -75.614036   Apartamento
# 7313                            SEÑORIAL  6.167286 -75.583696   Apartamento
# 7370                             Bavaria  6.151145 -75.636623          Casa
# 6443                             La mina  6.152162 -75.581125   Apartamento
# 3970                       sabaneta real  6.144799 -75.619519          Casa
# 3571                         San Joaquin  6.246974 -75.585161   Apartamento
# 312                        La candelaria  6.247638 -75.565815   Apartamento
# 1435                 Sabaneta La Doctora  6.150486 -75.616879   Apartamento
# 8262                         El diamante  6.247638 -75.565815   Apartamento
# 1807                           San pablo  6.219887 -75.582579          Casa
# 35                                Zuñiga  6.167286 -75.583696   Apartamento
# 7766  Conjunto residencial san fransisco  6.159714 -75.574775   Apartamento
# 9757                          Aves Maria  6.144721 -75.610881   Apartamento
# 851                            Florencia  6.309400 -75.565526   Apartamento
# 2194                           El portal  6.169787 -75.591405   Apartamento
# 1312                         las lomitas  6.144643 -75.605308   Apartamento
#
#       rooms  baths   area  administration_price  age  garages  stratum  \
# 6565    3.0    1.0   78.0                   0.0  3.0      1.0        3
# 9296    3.0    2.0   55.0              190000.0  1.0      NaN        4
# 361     2.0    2.0  115.0              460000.0  1.0      1.0        4
# 1263    2.0    2.0   87.0              600000.0  2.0      1.0        6
# 3043    3.0    2.0   71.0              234000.0  1.0      2.0        4
# 9513    3.0    4.0  244.0              665000.0  3.0      2.0        5
# 1157    2.0    1.0   42.0              170000.0  NaN      NaN        4
# 2875    3.0    2.0   54.0              210000.0  2.0      1.0        4
# 7352    3.0    2.0  101.0              336000.0  3.0      1.0        5
# 6107    4.0    2.0  117.0                   0.0  4.0      NaN        3
# 8719    3.0    2.0   90.0              330000.0  0.0      1.0        5
# 4495    5.0    2.0  150.0                   0.0  NaN      NaN        4
# 7376    2.0    1.0   55.0              260000.0  2.0      NaN        4
# 7638    3.0    1.0   70.0                   0.0  NaN      NaN        3
# 2397    3.0    2.0   69.0              270000.0  2.0      1.0        4
# 7313    3.0    2.0   65.0              295000.0  NaN      1.0        4
# 7370    3.0    3.0  119.0              285000.0  2.0      1.0        4
# 6443    2.0    2.0   75.0                   0.0  1.0      2.0        5
# 3970    4.0    3.0  270.0                   0.0  NaN      1.0        4
# 3571    4.0    5.0  160.0                   0.0  4.0      NaN        4
# 312     3.0    3.0  200.0              500000.0  4.0      2.0        6
# 1435    3.0    2.0   60.0                   0.0  NaN      1.0        2
# 8262    3.0    3.0  142.0                   0.0  NaN      NaN        6
# 1807    2.0    2.0   77.0                   0.0  3.0      NaN        4
# 35      3.0    2.0   93.0              601000.0  1.0      1.0        5
# 7766    3.0    4.0  135.0              536000.0  1.0      2.0        5
# 9757    3.0    3.0  114.0              376860.0  2.0      1.0        4
# 851     3.0    2.0   88.0                   0.0  1.0      NaN        3
# 2194    4.0    2.0  110.0                   0.0  3.0      NaN        4
# 1312    3.0    3.0  160.0              585000.0  1.0      2.0        4
#
#        price   pred_price
# 6565   250.0  1145.225893
# 9296   310.0  1025.445410
# 361    560.0   888.554048
# 1263   730.0   992.545345
# 3043   395.0   834.971955
# 9513  1300.0  1343.396403
# 1157   265.0   995.338820
# 2875   240.0  1024.962970
# 7352   580.0   916.932841
# 6107   620.0   920.919325
# 8719   460.0   956.014447
# 4495   400.0   844.653434
# 7376   305.0  1010.633104
# 7638   250.0   998.563795
# 2397   360.0   835.754830
# 7313   380.0   894.870727
# 7370   800.0   868.410442
# 6443   452.0   898.917354
# 3970   980.0   986.317223
# 3571   900.0  1434.130770
# 312    885.0  1244.393999
# 1435   270.0   818.858929
# 8262   800.0  1079.158232
# 1807   280.0   872.259375
# 35     600.0   952.404254
# 7766   950.0  1292.617113
# 9757   450.0   854.953259
# 851    250.0  1036.639079
# 2194   400.0   922.478876
# 1312   910.0   946.192204

# %% [markdown]
# ### 10. Use AutoML
# Use autoML to automate the supervised regression model training
